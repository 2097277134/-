# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
import pyrealsense2 as rs
import serial
import numpy as np
import time
from threading import Thread
import threading
import csv
import DataDeal265 as dd
import struct
import RPi.GPIO as GPIO
import queue
import torch
import cv2
import numpy as np
import ipywidgets
import pyzbar.pyzbar as pyzbar
import math
import time
from cnn import *

cnn=CNN()#加载网络
# 加载网络模型
cnn.load_state_dict(torch.load('weight/pytorchp.pkl',map_location='cpu'))
CopterTakingOff =1
TargetPosition = [0.0,0.0,0.0]
# cp1=[0.0,0.0]#起点
# cp2=[-1,0.0]#数字识别点一
# cp3=[-1,1]#二维码识别点
# X坐标 Y坐标
cp1=[0.0,0.0]#起点
cp2=[-5.4,0.3]#数字识别点一
cp3=[-2.5,2.65]#二维码识别点
#左边路径
cp4=[-3.5,2.5]
cp5=[-3.5,3.5]
cp6=[-3.1,4.0]
#右边路径
cp7=[-1.5,2.5]
cp8=[-1.5,3.5]
cp9=[-3.1,4.0]

cp10=[-2.5,7.7]#数字识别点二
cp11=[0.0,6.8]#降落点一
cp112=[0.0,6.6]#降落点二
roqu=queue.Queue()
roqu.put(cp1)
roqu.put(cp2)
#roqu.put(cp3)
font_scale=1.5 #字体大小
font=cv2.FONT_HERSHEY_PLAIN#字体类型
imageFlag=True

# %%
# 字符串对比
def StrComparison(str1,str2):
    n = len(str1)
    res = []
    for x in str1:
        if x in str2:
            res.append(x)
    #print (n)
    return (n-len(res))
#二维码识别
def QRCode():
    signRight=0
    signLeft=0
    right =False
    left = False
    while True:
        ret,img_QR=cap.read()
        gray = cv2.cvtColor(img_QR, cv2.COLOR_BGR2GRAY)
        barcodes = pyzbar.decode(gray)
        for barcode in barcodes:# 循环读取检测到的条形码
            # 绘条形码、二维码多边形轮廓
            points =[]
            for point in barcode.polygon:
                points.append([point[0], point[1]])
            points = np.array(points,dtype=np.int32).reshape(-1,1, 2)
            cv2.polylines(img_QR, [points], isClosed=True, color=(0,0,255),thickness=2)

            # 条形码数据为字节对象，所以如果我们想把它画出来
            # 需要先把它转换成字符串
            barcodeData = barcode.data.decode("UTF-8") #先解码成字符串

            # 绘出图像上的条形码数据和类型

            # print(barcodeData)
            cv2.putText(img_QR, barcodeData, (barcode.polygon[0].x, barcode.polygon[0].y - 10),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
            if StrComparison(str('right'),barcodeData )<=1:
                signRight+=1
                if signRight == 5:
                    right = True
                    print('right')
                    

            if StrComparison( str('left'),barcodeData)<=1:
                signLeft+=1
                if signLeft == 5:
                    left = True
                    print('left')
        if left or right:
            break
        wid.value = cv2.imencode('.jpg',img_QR)[1].tobytes()
    return right,left
        
#Roi1  不使用      
def findRoi1(frame, thresValue,kernel):
    rois = []
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray1 = cv2.dilate(gray,None,iterations=2)
    gray2 = cv2.erode(gray1,None,iterations=2)
    edges = cv2.absdiff(gray,gray2)
    x = cv2.Sobel(edges,cv2.CV_16S,1,0)
    y = cv2.Sobel(edges,cv2.CV_16S,0,1)
    absX = cv2.convertScaleAbs(x)
    absY = cv2.convertScaleAbs(y)
    dst = cv2.addWeighted(absX,0.5,absY,0.5,0)
    ret, ddst = cv2.threshold(dst,thresValue,255,cv2.THRESH_BINARY)
    contours, hierarchy = cv2.findContours(ddst,cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    area = []
    rois = []
    for k in range(len(contours)):
        area.append(cv2.contourArea(contours[k]))
    if area  :  
        max_idx = np.argmax(np.array(area))
        x, y, w, h = cv2.boundingRect(contours[max_idx])
        rois.append((x,y,w,h))
    return rois, edges,area
#Roi    
def findRoi(frame, thresValue,kernel):
    rois = []
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray1 = cv2.dilate(gray,kernel,iterations=2)
    # gray2 = cv2.erode(gray1,None,iterations=2)
    ret, ddst = cv2.threshold(gray1,thresValue,255,cv2.THRESH_BINARY_INV)
    # ret, ddst = cv2.threshold(gray1,thresValue,255,cv2.THRESH_OTSU+cv2.THRESH_BINARY_INV)
    # contours, hierarchy = cv2.findContours(ddst,cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours, hierarchy = cv2.findContours(ddst,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    area = []
    rois = []
    for k in range(len(contours)):
        area.append(cv2.contourArea(contours[k]))
    if area  :  
        max_idx = np.argmax(np.array(area))
        x, y, w, h = cv2.boundingRect(contours[max_idx])
        rois.append((x,y,w,h))
    return rois, ddst,area
    
    
    
#寻找数字
def findDigit(cnn, roi, thresValue):
    ret, th = cv2.threshold(roi, thresValue, 255, cv2.THRESH_BINARY)
    # ret, th = cv2.threshold(roi,thresValue,255,cv2.THRESH_OTSU)
    th = cv2.resize(th,(28,28),interpolation=cv2.INTER_AREA)
    newing=[[th]]
    newing = torch.Tensor(np.array(newing)).float()/255. 
    predicions=cnn(newing)
    retult=torch.argmax(predicions).detach().numpy()
    return retult,th      
def mnist():
    Addo=0
    Adde=0
    odd=False
    even=False
    while True:
        ret,frame=cap.read()
        rois,edges,area = findRoi(frame, thresValue,kernel)
        digits = []
        if rois: 
            x, y, w, h=rois[0]
            x_small=int(x+(w-h)/2)
            if  x_small<0:
                    x_small = 0
            # digit,th = findDigit(cnn,edges[y:y+h,x:x+w], 70)
            digit,th = findDigit(cnn,edges[y:y+h, x_small: x_small+h], thresValue)
            
                    #奇数判断
            if int(digit)%2==1:
                Addo+=1
                if Addo==10:
                    odd=True
                    break
            #偶数判断    
            elif int(digit)%2!=1:
                Adde+=1
                if Adde == 10:
                    even=True
                    break
            cv2.rectangle(frame, (int(x+(w-h)/2),y), (int(x+(w+h)/2),y+h), (153,153,0), 2)
            cv2.putText(frame, str(digit), (x,y), cv2.FONT_HERSHEY_SIMPLEX, 1, (127,0,255), 2)
            #cv2.putText(frame, str(digit), (x,y), cv2.FONT_HERSHEY_SIMPLEX, 1, (127,0,255), 2)
            newEdges = cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR)
            newFrame = np.hstack((frame,newEdges))
            wid.value = cv2.imencode('.jpg',newFrame)[1].tobytes()        
    return odd,even
#路径点更新图像识别线程
def Router():
    global timer
    global routeNodeIndex
    global SendTargetPos
    global CopterLanding
    global LaserArray
    global LaserDistance
    global FlightMode
    global CopterTakingOff
    global routeStartFlag
    global tarx
    global tary
    global routerFlag
    global dataBuf
    oddflag=0
    evenflag=0
    while True:
        SendTargetPos = 1       
        if math.sqrt((tarx-pos_Y)**2+(tary+pos_X)**2)<0.1 and routeStartFlag and routerFlag:
            if imageFlag:
            #数字识别启动判断    
                if (math.sqrt((cp2[0]-pos_Y)**2+(cp2[1]+pos_X)**2)<0.1 or math.sqrt((cp10[0]-pos_Y)**2+(cp10[1]+pos_X)*2)<0.1): 
                    #数字识别
                    odd,even = mnist()
                    if odd:
                        oddflag+=1
                        print('odd')
                    elif even:
                        evenflag+=1
                        print('even')
                #二维码识别启动判断
                if math.sqrt((cp3[0]-pos_Y)**2+(cp3[1]+pos_X)**2)<0.1: 
                    #二维码识别   
                    right,left=QRCode() 
                    if left:
                        #左边路径入队
                        roqu.put(cp4)
                        roqu.put(cp5)
                        roqu.put(cp6)
                        roqu.put(cp10)
                        print('left')
                    if right:
                        #右边路径入队  
                        roqu.put(cp7)
                        roqu.put(cp8)
                        roqu.put(cp9)
                        roqu.put(cp10)
                        print('right')
                if ((cp10[0]-pos_Y)**2+(cp10[1]+pos_X)*2)<0.1 and (oddflag==2 or evenflag==2):
                    #终点1入队
                    roqu.put(cp11)
                if ((cp10[0]-pos_Y)**2+(cp10[1]+pos_X)*2)<0.1 and oddflag==1 and evenflag==1:

                    #终点2入队
                    roqu.put(cp12)
            if not roqu.empty():
                TargetPosition=roqu.get()
                routeNodeIndex+=1
                tarx=float(TargetPosition[0])
                tary=float(TargetPosition[1])
                print ("route node %d: x : %.1f , y : %.1f  " %(routeNodeIndex,tarx,tary))
                a=0
                time.sleep(1)
            else:
                # pipe.stop()
                #2SendTargetPos = 0
                CopterTakingOff = 1
                CopterLanding = 1
                routeNodeIndex= 1
                closeRouter = True
                print ("Landing")    
                routerFlag=False
    

           

#串口通信线程
def PortCom(port):
    global pipe
    global cfg
    global SendTargetPos
    global CopterLanding
    global CopterTakingOff
    global _265Ready
    global GetOnceCmd
    global routeNodeIndex
    global routeStartFlag
    global closeRouter
    closeRouter = False
    while(True):
#         size=port.inWaiting()
#         if(size!=0):
        if closeRouter:
            router.cancel()
        response = port.readline()
        if(response !=None):
            port.flushInput()        
            CmdStr1 = str(b'Start265\n')
            CmdStr2 = str(b'Departures\n')
            CmdStr3 = str(b'Refresh265\n')
            CMD = str(response)            
            #刷新265
            if( ( StrComparison( CMD ,CmdStr1 )<=1)  and  GetOnceCmd ==False):
                print(StrComparison( CMD ,CmdStr1 ),response,CMD)
                # Declare RealSense pipeline, encapsulating the actual device and sensors
                pipe = rs.pipeline()
#                 try:
#                     pipe.stop()
#                 except:
#                     print("Error1")
                # Build config object and request pose data
                cfg = rs.config()
                cfg.enable_stream(rs.stream.pose,rs.format.any,framerate=200)
                # Start streaming with requested config
                pipe.start(cfg)
                dd.initData()
                SendTargetPos = 0
                CopterLanding = 0
                _265Ready=True
                GetOnceCmd =True 
                routeStartFlag = True

            elif( ( StrComparison(CMD ,CmdStr2 )<=1)  and  CopterTakingOff == 1 ):
                print(StrComparison(CMD ,CmdStr2 ),response,CMD)
                print("Get!")
                router = Thread(target=Router, args=())
                router.start()
                CopterTakingOff = 0
                
            elif( StrComparison(CMD ,CmdStr3 )<=1):
                _265Ready = False
                GetOnceCmd = False
                routeNodeIndex= 1
                CopterTakingOff =1
                routeStartFlag = False
                print("ReStart!")
                print( StrComparison(CMD ,CmdStr3 ),response,CMD)
                try:
                    pipe.stop()
                    time.sleep(1.0)               
                except:
                    print("Error2")  
            response = 0
            CMD = 0
       
                        
        time.sleep(0.02) 

if __name__ == '__main__':
    global routeNodeIndex
    global SendTargetPos
    global CopterLanding
    global LaserArray
    global LaserDistance
    global FlightMode
    global pipe
    global _265Ready
    global GetOnceCmd
    global CheckSum
    global tarx
    global tary
    global routerFlag
    global dataBuf
    port = serial.Serial(port="/dev/ttyAMA0",baudrate=230400,stopbits=1,parity=serial.PARITY_NONE,timeout=1000)
    kernel = np.ones((4, 4), np.uint8) #膨胀算子
    thresValue=150                      #阈值
    wid = ipywidgets.Image() 
    #打开摄像头  
    cap=cv2.VideoCapture(0)
    if not cap.isOpened():
        cap=cv2.VideoCapture(1)
    if not cap.isOpened():
        raise IOError('Can not open video')
    #设置摄像头参数    
    cap.set(cv2.CAP_PROP_FPS, 30)
    cap.set(cv2.CAP_PROP_FRAME_WIDTH,320)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT,240)    
    ret,img = cap.read()    
       
    #串口通信线程
    thread_Serial = Thread(target=PortCom, args=(port,))
    thread_Serial.start()
    #导入
    TargetPosition=roqu.get()
    tarx=TargetPosition[0]
    tary=TargetPosition[1]
    #输出路径点个数
    # print ("route nodes num is : " + str(routeNodeNum-1))
    routeNodeIndex = 1
    _265Ready =False
    GetOnceCmd =False
    CheckSum =0 
    dataBuf = [0]*65
    LaserArray =0
    LaserDistance=0.0
    FlightMode =0
    routerFlag =True
    display(wid)  
    try:
        while(True):
            # ret,Frame = cap.read()
            if _265Ready:
                # Wait for the next set of frames from the camera
                frames = pipe.wait_for_frames()
                # Fetch pose frame
                pose = frames.get_pose_frame()
                if pose:   
                    # Print some of the pose data to the terminal
                    data = pose.get_pose_data()
                    dataBuf,pos_X,pos_Y,pos_Z,Euler=dd.solveData(data)
                    if(SendTargetPos == 1):           
                        # posZ = TargetPosition[2]
                        posZ=0.0
                        dataBuf[43] = 0x20
                        posX_buf = struct.pack("f",tarx) 
                        dataBuf[44] = posX_buf[0]
                        dataBuf[45] = posX_buf[1]
                        dataBuf[46] = posX_buf[2]
                        dataBuf[47] = posX_buf[3] 
                        posY_buf = struct.pack("f",tary)
                        dataBuf[48] = posY_buf[0]
                        dataBuf[49] = posY_buf[1]
                        dataBuf[50] = posY_buf[2]
                        dataBuf[51] = posY_buf[3]
                        posZ_buf = struct.pack("f",posZ) 
                        dataBuf[52] = posZ_buf[0]
                        dataBuf[53] = posZ_buf[1]
                        dataBuf[54] = posZ_buf[2]
                        dataBuf[55] = posZ_buf[3]

                        dataBuf[56] = LaserArray              
                        Laser_Dis = struct.pack("f",LaserDistance)
                        dataBuf[57] = Laser_Dis[0]
                        dataBuf[58] = Laser_Dis[1]
                        dataBuf[59] = Laser_Dis[2]             
                        dataBuf[60] = Laser_Dis[3]                  
                        dataBuf[61] = FlightMode
                   
                    if CopterLanding==1:
                        dataBuf[62] = 0xA5
                    else:
                        dataBuf[62] = 0x00
                    
                    for i in range(0,62):                     
                        CheckSum =  CheckSum + dataBuf[i]
                
                    dataBuf[63] = 0xAA
                    dataBuf[64] = CheckSum & 0x00ff
                    
                    print("\rrpy_rad[0]:{:.2f},rpy_rad[1]:{:.2f},rpy_rad[2]:{:.2f} ,X:{:.2f},Y:{:.2f},Z:{:.2f} ".format(Euler[0]*57.3,Euler[1]*57.3,Euler[2]*57.3,pos_Y,-pos_X,pos_Z),end="")
                    port.write(dataBuf)
                    CheckSum = 0
#                     pipe.stop()
            else:
                dataBuf[0] = 0x55
                dataBuf[1] = 0xAA
                dataBuf[2] = 0xFF
                dataBuf[63] = 0xAA
                dataBuf[64] = 0x00
                port.write(dataBuf)
                time.sleep(0.1)
            # wid.value = cv2.imencode('.jpg',Frame)[1].tobytes()
    finally:
        print("some erro")
#         pipe.stop()
# Out:
# Image(value=b'')
# 0 b'Start265\n' b'Start265\n'
# rpy_rad[0]:-45.62,rpy_rad[1]:-0.55,rpy_rad[2]:-3.08 ,X:-0.08,Y:0.04,Z:0.34 0 b'Departures\n' b'Departures\n'
# Get!
# route node 2: x : -1.0 , y : 0.0
# rpy_rad[0]:-44.87,rpy_rad[1]:0.73,rpy_rad[2]:-4.03 ,X:-0.90,Y:0.00,Z:0.38 Landing
# 降落
# rpy_rad[0]:-44.79,rpy_rad[1]:0.66,rpy_rad[2]:-4.03 ,X:-0.90,Y:-0.01,Z:0.38 降落
# rpy_rad[0]:-44.17,rpy_rad[1]:0.62,rpy_rad[2]:-4.02 ,X:-0.91,Y:-0.01,Z:0.36 降落
# rpy_rad[0]:-44.28,rpy_rad[1]:0.59,rpy_rad[2]:-4.04 ,X:-0.92,Y:-0.02,Z:0.36 降落
# rpy_rad[0]:-44.97,rpy_rad[1]:0.47,rpy_rad[2]:-4.09 ,X:-0.92,Y:-0.03,Z:0.37 降落
# rpy_rad[0]:-45.28,rpy_rad[1]:0.42,rpy_rad[2]:-4.13 ,X:-0.93,Y:-0.03,Z:0.37 降落
# rpy_rad[0]:-45.56,rpy_rad[1]:0.33,rpy_rad[2]:-4.13 ,X:-0.93,Y:-0.04,Z:0.39 降落
# rpy_rad[0]:-45.82,rpy_rad[1]:0.23,rpy_rad[2]:-4.17 ,X:-0.93,Y:-0.05,Z:0.39 降落
# rpy_rad[0]:-45.73,rpy_rad[1]:0.07,rpy_rad[2]:-4.17 ,X:-0.93,Y:-0.06,Z:0.39 降落
# rpy_rad[0]:-45.39,rpy_rad[1]:0.03,rpy_rad[2]:-4.17 ,X:-0.94,Y:-0.06,Z:0.37 降落
# rpy_rad[0]:-45.11,rpy_rad[1]:-0.02,rpy_rad[2]:-4.21 ,X:-0.95,Y:-0.06,Z:0.37 降落
# rpy_rad[0]:-45.18,rpy_rad[1]:-0.04,rpy_rad[2]:-4.22 ,X:-0.95,Y:-0.06,Z:0.36 降落
# rpy_rad[0]:-45.22,rpy_rad[1]:-0.08,rpy_rad[2]:-4.25 ,X:-0.95,Y:-0.07,Z:0.36 降落
# rpy_rad[0]:-46.31,rpy_rad[1]:-0.29,rpy_rad[2]:-4.30 ,X:-0.95,Y:-0.08,Z:0.38 降落
# rpy_rad[0]:-45.83,rpy_rad[1]:-0.36,rpy_rad[2]:-4.24 ,X:-0.96,Y:-0.09,Z:0.37 降落
# rpy_rad[0]:-46.14,rpy_rad[1]:-0.38,rpy_rad[2]:-4.30 ,X:-0.96,Y:-0.09,Z:0.37 降落
# rpy_rad[0]:-45.79,rpy_rad[1]:-0.48,rpy_rad[2]:-4.28 ,X:-0.97,Y:-0.09,Z:0.36 降落
# rpy_rad[0]:-45.73,rpy_rad[1]:-0.48,rpy_rad[2]:-4.43 ,X:-0.97,Y:-0.09,Z:0.36 降落
# rpy_rad[0]:-46.31,rpy_rad[1]:-0.57,rpy_rad[2]:-4.42 ,X:-0.98,Y:-0.11,Z:0.37 降落
# rpy_rad[0]:-46.41,rpy_rad[1]:-0.63,rpy_rad[2]:-4.47 ,X:-0.98,Y:-0.11,Z:0.37 降落
# rpy_rad[0]:-46.56,rpy_rad[1]:-0.59,rpy_rad[2]:-4.38 ,X:-0.99,Y:-0.12,Z:0.37 降落
# rpy_rad[0]:-46.38,rpy_rad[1]:-0.69,rpy_rad[2]:-4.47 ,X:-0.99,Y:-0.12,Z:0.36 降落
# rpy_rad[0]:-46.39,rpy_rad[1]:-0.71,rpy_rad[2]:-4.51 ,X:-1.00,Y:-0.13,Z:0.36 降落
# rpy_rad[0]:-46.55,rpy_rad[1]:-0.80,rpy_rad[2]:-4.59 ,X:-1.00,Y:-0.13,Z:0.37 降落
# rpy_rad[0]:-46.93,rpy_rad[1]:-0.85,rpy_rad[2]:-4.69 ,X:-1.00,Y:-0.13,Z:0.37 降落
# rpy_rad[0]:-47.36,rpy_rad[1]:-0.89,rpy_rad[2]:-4.73 ,X:-1.01,Y:-0.14,Z:0.38 降落
# rpy_rad[0]:-46.89,rpy_rad[1]:-0.94,rpy_rad[2]:-4.69 ,X:-1.01,Y:-0.14,Z:0.37 降落
# rpy_rad[0]:-46.96,rpy_rad[1]:-0.99,rpy_rad[2]:-4.73 ,X:-1.02,Y:-0.15,Z:0.37 降落
# rpy_rad[0]:-46.64,rpy_rad[1]:-1.05,rpy_rad[2]:-4.78 ,X:-1.02,Y:-0.15,Z:0.37 降落
# rpy_rad[0]:-46.91,rpy_rad[1]:-1.04,rpy_rad[2]:-4.80 ,X:-1.02,Y:-0.15,Z:0.37 降落
# rpy_rad[0]:-46.46,rpy_rad[1]:-1.13,rpy_rad[2]:-4.90 ,X:-1.03,Y:-0.15,Z:0.36 降落
# rpy_rad[0]:-46.83,rpy_rad[1]:-1.15,rpy_rad[2]:-4.92 ,X:-1.03,Y:-0.15,Z:0.37 降落
# rpy_rad[0]:-46.90,rpy_rad[1]:-1.17,rpy_rad[2]:-4.97 ,X:-1.03,Y:-0.15,Z:0.37 降落
# rpy_rad[0]:-47.04,rpy_rad[1]:-1.09,rpy_rad[2]:-4.92 ,X:-1.04,Y:-0.16,Z:0.37 降落
# rpy_rad[0]:-46.99,rpy_rad[1]:-1.12,rpy_rad[2]:-4.95 ,X:-1.04,Y:-0.16,Z:0.37 降落
# rpy_rad[0]:-46.93,rpy_rad[1]:-1.09,rpy_rad[2]:-5.00 ,X:-1.04,Y:-0.16,Z:0.37 降落
# rpy_rad[0]:-46.53,rpy_rad[1]:-1.11,rpy_rad[2]:-4.98 ,X:-1.05,Y:-0.16,Z:0.36 降落
# rpy_rad[0]:-46.94,rpy_rad[1]:-1.11,rpy_rad[2]:-5.07 ,X:-1.05,Y:-0.16,Z:0.37 降落
# rpy_rad[0]:-47.24,rpy_rad[1]:-1.08,rpy_rad[2]:-5.11 ,X:-1.05,Y:-0.16,Z:0.37 降落
# rpy_rad[0]:-47.72,rpy_rad[1]:-1.07,rpy_rad[2]:-5.21 ,X:-1.06,Y:-0.16,Z:0.38 降落
# rpy_rad[0]:-47.22,rpy_rad[1]:-1.13,rpy_rad[2]:-5.17 ,X:-1.06,Y:-0.16,Z:0.38 降落
# rpy_rad[0]:-46.90,rpy_rad[1]:-1.11,rpy_rad[2]:-5.18 ,X:-1.07,Y:-0.16,Z:0.37 降落
# rpy_rad[0]:-46.66,rpy_rad[1]:-1.13,rpy_rad[2]:-5.24 ,X:-1.07,Y:-0.16,Z:0.37 降落
# rpy_rad[0]:-46.63,rpy_rad[1]:-1.16,rpy_rad[2]:-5.30 ,X:-1.07,Y:-0.16,Z:0.37 降落
# rpy_rad[0]:-46.98,rpy_rad[1]:-1.24,rpy_rad[2]:-5.35 ,X:-1.08,Y:-0.16,Z:0.38 降落
# rpy_rad[0]:-46.89,rpy_rad[1]:-1.24,rpy_rad[2]:-5.35 ,X:-1.08,Y:-0.16,Z:0.38 降落
# rpy_rad[0]:-46.79,rpy_rad[1]:-1.12,rpy_rad[2]:-5.26 ,X:-1.08,Y:-0.17,Z:0.38 降落
# rpy_rad[0]:-46.31,rpy_rad[1]:-1.11,rpy_rad[2]:-5.24 ,X:-1.09,Y:-0.17,Z:0.37 降落
# rpy_rad[0]:-46.08,rpy_rad[1]:-1.11,rpy_rad[2]:-5.23 ,X:-1.09,Y:-0.17,Z:0.37 降落
# rpy_rad[0]:-45.95,rpy_rad[1]:-1.12,rpy_rad[2]:-5.22 ,X:-1.09,Y:-0.17,Z:0.36 降落
# rpy_rad[0]:-46.06,rpy_rad[1]:-1.12,rpy_rad[2]:-5.25 ,X:-1.09,Y:-0.17,Z:0.36 降落
# rpy_rad[0]:-46.63,rpy_rad[1]:-1.08,rpy_rad[2]:-5.28 ,X:-1.09,Y:-0.17,Z:0.37 降落
# rpy_rad[0]:-46.73,rpy_rad[1]:-1.10,rpy_rad[2]:-5.27 ,X:-1.10,Y:-0.17,Z:0.38 降落
# rpy_rad[0]:-47.19,rpy_rad[1]:-1.07,rpy_rad[2]:-5.31 ,X:-1.10,Y:-0.17,Z:0.39 降落
# rpy_rad[0]:-46.75,rpy_rad[1]:-1.12,rpy_rad[2]:-5.27 ,X:-1.10,Y:-0.17,Z:0.39 降落
# rpy_rad[0]:-46.41,rpy_rad[1]:-1.09,rpy_rad[2]:-5.24 ,X:-1.10,Y:-0.17,Z:0.38 降落
# rpy_rad[0]:-46.32,rpy_rad[1]:-1.06,rpy_rad[2]:-5.23 ,X:-1.11,Y:-0.17,Z:0.38 降落
# rpy_rad[0]:-46.30,rpy_rad[1]:-1.05,rpy_rad[2]:-5.25 ,X:-1.11,Y:-0.17,Z:0.38 降落
# rpy_rad[0]:-46.26,rpy_rad[1]:-1.05,rpy_rad[2]:-5.25 ,X:-1.11,Y:-0.17,Z:0.39 降落
# rpy_rad[0]:-46.45,rpy_rad[1]:-1.04,rpy_rad[2]:-5.29 ,X:-1.11,Y:-0.17,Z:0.39 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:-1.02,rpy_rad[2]:-5.21 ,X:-1.11,Y:-0.17,Z:0.39 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:-1.01,rpy_rad[2]:-5.21 ,X:-1.12,Y:-0.17,Z:0.39 降落
# rpy_rad[0]:-45.81,rpy_rad[1]:-1.02,rpy_rad[2]:-5.18 ,X:-1.12,Y:-0.17,Z:0.37 降落
# rpy_rad[0]:-45.57,rpy_rad[1]:-1.03,rpy_rad[2]:-5.19 ,X:-1.12,Y:-0.16,Z:0.35 降落
# rpy_rad[0]:-45.74,rpy_rad[1]:-0.99,rpy_rad[2]:-5.20 ,X:-1.12,Y:-0.16,Z:0.37 降落
# rpy_rad[0]:-46.05,rpy_rad[1]:-0.98,rpy_rad[2]:-5.21 ,X:-1.12,Y:-0.16,Z:0.37 降落
# rpy_rad[0]:-46.12,rpy_rad[1]:-0.97,rpy_rad[2]:-5.20 ,X:-1.13,Y:-0.16,Z:0.38 降落
# rpy_rad[0]:-45.81,rpy_rad[1]:-0.95,rpy_rad[2]:-5.08 ,X:-1.13,Y:-0.17,Z:0.38 降落
# rpy_rad[0]:-45.92,rpy_rad[1]:-0.96,rpy_rad[2]:-5.14 ,X:-1.13,Y:-0.17,Z:0.38 降落
# rpy_rad[0]:-45.66,rpy_rad[1]:-0.96,rpy_rad[2]:-5.07 ,X:-1.13,Y:-0.16,Z:0.38 降落
# rpy_rad[0]:-45.65,rpy_rad[1]:-0.93,rpy_rad[2]:-5.09 ,X:-1.13,Y:-0.16,Z:0.38 降落
# rpy_rad[0]:-45.83,rpy_rad[1]:-0.89,rpy_rad[2]:-5.11 ,X:-1.13,Y:-0.16,Z:0.38 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:-0.88,rpy_rad[2]:-5.08 ,X:-1.14,Y:-0.16,Z:0.39 降落
# rpy_rad[0]:-45.81,rpy_rad[1]:-0.91,rpy_rad[2]:-5.07 ,X:-1.14,Y:-0.16,Z:0.39 降落
# rpy_rad[0]:-46.32,rpy_rad[1]:-0.87,rpy_rad[2]:-5.02 ,X:-1.14,Y:-0.16,Z:0.40 降落
# rpy_rad[0]:-46.02,rpy_rad[1]:-0.87,rpy_rad[2]:-4.99 ,X:-1.15,Y:-0.16,Z:0.39 降落
# rpy_rad[0]:-45.78,rpy_rad[1]:-0.89,rpy_rad[2]:-4.97 ,X:-1.15,Y:-0.16,Z:0.39 降落
# rpy_rad[0]:-45.99,rpy_rad[1]:-0.89,rpy_rad[2]:-4.99 ,X:-1.15,Y:-0.16,Z:0.39 降落
# rpy_rad[0]:-46.12,rpy_rad[1]:-0.87,rpy_rad[2]:-5.02 ,X:-1.15,Y:-0.16,Z:0.39 降落
# rpy_rad[0]:-46.39,rpy_rad[1]:-0.89,rpy_rad[2]:-5.07 ,X:-1.15,Y:-0.15,Z:0.40 降落
# rpy_rad[0]:-46.26,rpy_rad[1]:-0.88,rpy_rad[2]:-5.04 ,X:-1.15,Y:-0.15,Z:0.40 降落
# rpy_rad[0]:-45.68,rpy_rad[1]:-0.88,rpy_rad[2]:-4.91 ,X:-1.15,Y:-0.15,Z:0.39 降落
# rpy_rad[0]:-45.83,rpy_rad[1]:-0.89,rpy_rad[2]:-4.94 ,X:-1.15,Y:-0.15,Z:0.39 降落
# rpy_rad[0]:-45.37,rpy_rad[1]:-0.90,rpy_rad[2]:-4.88 ,X:-1.16,Y:-0.15,Z:0.39 降落
# rpy_rad[0]:-45.44,rpy_rad[1]:-0.90,rpy_rad[2]:-4.89 ,X:-1.16,Y:-0.15,Z:0.38 降落
# rpy_rad[0]:-45.27,rpy_rad[1]:-0.94,rpy_rad[2]:-4.92 ,X:-1.16,Y:-0.14,Z:0.38 降落
# rpy_rad[0]:-45.69,rpy_rad[1]:-0.89,rpy_rad[2]:-4.83 ,X:-1.16,Y:-0.15,Z:0.39 降落
# rpy_rad[0]:-45.70,rpy_rad[1]:-0.88,rpy_rad[2]:-4.86 ,X:-1.16,Y:-0.14,Z:0.39 降落
# rpy_rad[0]:-45.58,rpy_rad[1]:-0.89,rpy_rad[2]:-4.84 ,X:-1.16,Y:-0.14,Z:0.38 降落
# rpy_rad[0]:-45.53,rpy_rad[1]:-0.87,rpy_rad[2]:-4.77 ,X:-1.16,Y:-0.14,Z:0.38 降落
# rpy_rad[0]:-45.35,rpy_rad[1]:-0.88,rpy_rad[2]:-4.75 ,X:-1.16,Y:-0.14,Z:0.37 降落
# rpy_rad[0]:-45.57,rpy_rad[1]:-0.88,rpy_rad[2]:-4.73 ,X:-1.17,Y:-0.14,Z:0.38 降落
# rpy_rad[0]:-45.72,rpy_rad[1]:-0.90,rpy_rad[2]:-4.74 ,X:-1.16,Y:-0.14,Z:0.38 降落
# rpy_rad[0]:-45.95,rpy_rad[1]:-0.96,rpy_rad[2]:-4.73 ,X:-1.16,Y:-0.14,Z:0.40 降落
# rpy_rad[0]:-45.45,rpy_rad[1]:-0.95,rpy_rad[2]:-4.63 ,X:-1.17,Y:-0.15,Z:0.40 降落
# rpy_rad[0]:-45.31,rpy_rad[1]:-0.96,rpy_rad[2]:-4.62 ,X:-1.17,Y:-0.14,Z:0.39 降落
# rpy_rad[0]:-45.27,rpy_rad[1]:-0.91,rpy_rad[2]:-4.63 ,X:-1.17,Y:-0.14,Z:0.39 降落
# rpy_rad[0]:-45.15,rpy_rad[1]:-0.90,rpy_rad[2]:-4.60 ,X:-1.17,Y:-0.14,Z:0.40 降落
# rpy_rad[0]:-45.71,rpy_rad[1]:-0.99,rpy_rad[2]:-4.53 ,X:-1.17,Y:-0.14,Z:0.42 降落
# rpy_rad[0]:-45.53,rpy_rad[1]:-0.96,rpy_rad[2]:-4.49 ,X:-1.17,Y:-0.14,Z:0.41 降落
# rpy_rad[0]:-45.68,rpy_rad[1]:-0.96,rpy_rad[2]:-4.49 ,X:-1.17,Y:-0.14,Z:0.41 降落
# rpy_rad[0]:-45.45,rpy_rad[1]:-0.92,rpy_rad[2]:-4.46 ,X:-1.17,Y:-0.14,Z:0.40 降落
# rpy_rad[0]:-44.53,rpy_rad[1]:-0.90,rpy_rad[2]:-4.45 ,X:-1.17,Y:-0.13,Z:0.39 降落
# rpy_rad[0]:-44.73,rpy_rad[1]:-0.90,rpy_rad[2]:-4.45 ,X:-1.17,Y:-0.13,Z:0.38 降落
# rpy_rad[0]:-45.54,rpy_rad[1]:-0.87,rpy_rad[2]:-4.41 ,X:-1.17,Y:-0.13,Z:0.40 降落
# rpy_rad[0]:-45.66,rpy_rad[1]:-0.86,rpy_rad[2]:-4.40 ,X:-1.17,Y:-0.13,Z:0.40 降落
# rpy_rad[0]:-46.07,rpy_rad[1]:-0.92,rpy_rad[2]:-4.40 ,X:-1.17,Y:-0.13,Z:0.42 降落
# rpy_rad[0]:-45.54,rpy_rad[1]:-0.92,rpy_rad[2]:-4.32 ,X:-1.17,Y:-0.13,Z:0.41 降落
# rpy_rad[0]:-44.91,rpy_rad[1]:-0.84,rpy_rad[2]:-4.26 ,X:-1.17,Y:-0.13,Z:0.40 降落
# rpy_rad[0]:-44.81,rpy_rad[1]:-0.83,rpy_rad[2]:-4.28 ,X:-1.17,Y:-0.13,Z:0.40 降落
# rpy_rad[0]:-45.35,rpy_rad[1]:-0.79,rpy_rad[2]:-4.24 ,X:-1.17,Y:-0.13,Z:0.40 降落
# rpy_rad[0]:-45.37,rpy_rad[1]:-0.79,rpy_rad[2]:-4.25 ,X:-1.17,Y:-0.13,Z:0.41 降落
# rpy_rad[0]:-45.27,rpy_rad[1]:-0.74,rpy_rad[2]:-4.14 ,X:-1.17,Y:-0.13,Z:0.41 降落
# rpy_rad[0]:-44.96,rpy_rad[1]:-0.75,rpy_rad[2]:-4.10 ,X:-1.17,Y:-0.13,Z:0.40 降落
# rpy_rad[0]:-44.56,rpy_rad[1]:-0.77,rpy_rad[2]:-4.10 ,X:-1.17,Y:-0.13,Z:0.39 降落
# rpy_rad[0]:-44.65,rpy_rad[1]:-0.72,rpy_rad[2]:-4.14 ,X:-1.16,Y:-0.12,Z:0.39 降落
# rpy_rad[0]:-45.23,rpy_rad[1]:-0.67,rpy_rad[2]:-4.05 ,X:-1.17,Y:-0.13,Z:0.40 降落
# rpy_rad[0]:-45.27,rpy_rad[1]:-0.64,rpy_rad[2]:-4.02 ,X:-1.16,Y:-0.13,Z:0.40 降落
# rpy_rad[0]:-45.39,rpy_rad[1]:-0.58,rpy_rad[2]:-3.97 ,X:-1.16,Y:-0.13,Z:0.41 降落
# rpy_rad[0]:-44.73,rpy_rad[1]:-0.58,rpy_rad[2]:-3.95 ,X:-1.16,Y:-0.13,Z:0.40 降落
# rpy_rad[0]:-44.98,rpy_rad[1]:-0.58,rpy_rad[2]:-3.94 ,X:-1.16,Y:-0.12,Z:0.39 降落
# rpy_rad[0]:-45.00,rpy_rad[1]:-0.61,rpy_rad[2]:-3.92 ,X:-1.16,Y:-0.13,Z:0.40 降落
# rpy_rad[0]:-45.35,rpy_rad[1]:-0.60,rpy_rad[2]:-3.86 ,X:-1.16,Y:-0.13,Z:0.41 降落
# rpy_rad[0]:-45.82,rpy_rad[1]:-0.60,rpy_rad[2]:-3.85 ,X:-1.16,Y:-0.13,Z:0.42 降落
# rpy_rad[0]:-45.67,rpy_rad[1]:-0.63,rpy_rad[2]:-3.86 ,X:-1.16,Y:-0.13,Z:0.43 降落
# rpy_rad[0]:-44.95,rpy_rad[1]:-0.61,rpy_rad[2]:-3.83 ,X:-1.16,Y:-0.13,Z:0.41 降落
# rpy_rad[0]:-44.69,rpy_rad[1]:-0.59,rpy_rad[2]:-3.79 ,X:-1.16,Y:-0.13,Z:0.41 降落
# rpy_rad[0]:-44.69,rpy_rad[1]:-0.52,rpy_rad[2]:-3.78 ,X:-1.16,Y:-0.13,Z:0.41 降落
# rpy_rad[0]:-45.61,rpy_rad[1]:-0.54,rpy_rad[2]:-3.81 ,X:-1.15,Y:-0.13,Z:0.45 降落
# rpy_rad[0]:-45.46,rpy_rad[1]:-0.62,rpy_rad[2]:-3.75 ,X:-1.15,Y:-0.13,Z:0.42 降落
# rpy_rad[0]:-45.10,rpy_rad[1]:-0.62,rpy_rad[2]:-3.66 ,X:-1.15,Y:-0.12,Z:0.42 降落
# rpy_rad[0]:-45.15,rpy_rad[1]:-0.55,rpy_rad[2]:-3.67 ,X:-1.15,Y:-0.13,Z:0.42 降落
# rpy_rad[0]:-45.25,rpy_rad[1]:-0.57,rpy_rad[2]:-3.71 ,X:-1.15,Y:-0.12,Z:0.42 降落
# rpy_rad[0]:-44.82,rpy_rad[1]:-0.48,rpy_rad[2]:-3.61 ,X:-1.14,Y:-0.12,Z:0.41 降落
# rpy_rad[0]:-45.35,rpy_rad[1]:-0.55,rpy_rad[2]:-3.62 ,X:-1.14,Y:-0.12,Z:0.42 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:-0.63,rpy_rad[2]:-3.60 ,X:-1.14,Y:-0.12,Z:0.43 降落
# rpy_rad[0]:-45.64,rpy_rad[1]:-0.57,rpy_rad[2]:-3.54 ,X:-1.14,Y:-0.12,Z:0.43 降落
# rpy_rad[0]:-45.27,rpy_rad[1]:-0.48,rpy_rad[2]:-3.54 ,X:-1.14,Y:-0.12,Z:0.42 降落
# rpy_rad[0]:-45.42,rpy_rad[1]:-0.45,rpy_rad[2]:-3.50 ,X:-1.13,Y:-0.12,Z:0.42 降落
# rpy_rad[0]:-45.31,rpy_rad[1]:-0.49,rpy_rad[2]:-3.54 ,X:-1.13,Y:-0.12,Z:0.42 降落
# rpy_rad[0]:-45.66,rpy_rad[1]:-0.46,rpy_rad[2]:-3.52 ,X:-1.13,Y:-0.12,Z:0.43 降落
# rpy_rad[0]:-45.81,rpy_rad[1]:-0.43,rpy_rad[2]:-3.51 ,X:-1.12,Y:-0.11,Z:0.43 降落
# rpy_rad[0]:-45.01,rpy_rad[1]:-0.39,rpy_rad[2]:-3.42 ,X:-1.12,Y:-0.11,Z:0.41 降落
# rpy_rad[0]:-45.35,rpy_rad[1]:-0.38,rpy_rad[2]:-3.40 ,X:-1.12,Y:-0.11,Z:0.41 降落
# rpy_rad[0]:-45.61,rpy_rad[1]:-0.33,rpy_rad[2]:-3.34 ,X:-1.12,Y:-0.11,Z:0.42 降落
# rpy_rad[0]:-45.55,rpy_rad[1]:-0.27,rpy_rad[2]:-3.30 ,X:-1.11,Y:-0.11,Z:0.41 降落
# rpy_rad[0]:-45.58,rpy_rad[1]:-0.24,rpy_rad[2]:-3.27 ,X:-1.11,Y:-0.11,Z:0.41 降落
# rpy_rad[0]:-44.88,rpy_rad[1]:-0.21,rpy_rad[2]:-3.33 ,X:-1.11,Y:-0.11,Z:0.40 降落
# rpy_rad[0]:-45.05,rpy_rad[1]:-0.19,rpy_rad[2]:-3.27 ,X:-1.11,Y:-0.11,Z:0.40 降落
# rpy_rad[0]:-45.62,rpy_rad[1]:-0.20,rpy_rad[2]:-3.28 ,X:-1.10,Y:-0.11,Z:0.42 降落
# rpy_rad[0]:-45.62,rpy_rad[1]:-0.18,rpy_rad[2]:-3.26 ,X:-1.10,Y:-0.11,Z:0.42 降落
# rpy_rad[0]:-45.36,rpy_rad[1]:-0.10,rpy_rad[2]:-3.14 ,X:-1.10,Y:-0.11,Z:0.41 降落
# rpy_rad[0]:-45.25,rpy_rad[1]:-0.07,rpy_rad[2]:-3.10 ,X:-1.10,Y:-0.11,Z:0.40 降落
# rpy_rad[0]:-45.45,rpy_rad[1]:-0.10,rpy_rad[2]:-3.16 ,X:-1.10,Y:-0.11,Z:0.42 降落
# rpy_rad[0]:-45.46,rpy_rad[1]:-0.07,rpy_rad[2]:-3.14 ,X:-1.09,Y:-0.10,Z:0.41 降落
# rpy_rad[0]:-45.69,rpy_rad[1]:-0.06,rpy_rad[2]:-3.11 ,X:-1.09,Y:-0.10,Z:0.43 降落
# rpy_rad[0]:-45.78,rpy_rad[1]:-0.10,rpy_rad[2]:-3.09 ,X:-1.09,Y:-0.10,Z:0.42 降落
# rpy_rad[0]:-45.21,rpy_rad[1]:0.00,rpy_rad[2]:-3.03 ,X:-1.09,Y:-0.10,Z:0.42 降落
# rpy_rad[0]:-45.57,rpy_rad[1]:-0.01,rpy_rad[2]:-3.02 ,X:-1.08,Y:-0.10,Z:0.42 降落
# rpy_rad[0]:-45.09,rpy_rad[1]:0.04,rpy_rad[2]:-3.06 ,X:-1.08,Y:-0.10,Z:0.41 降落
# rpy_rad[0]:-45.09,rpy_rad[1]:0.05,rpy_rad[2]:-3.08 ,X:-1.08,Y:-0.09,Z:0.41 降落
# rpy_rad[0]:-45.58,rpy_rad[1]:-0.00,rpy_rad[2]:-3.05 ,X:-1.07,Y:-0.09,Z:0.43 降落
# rpy_rad[0]:-45.60,rpy_rad[1]:-0.00,rpy_rad[2]:-2.98 ,X:-1.07,Y:-0.10,Z:0.43 降落
# rpy_rad[0]:-45.72,rpy_rad[1]:0.01,rpy_rad[2]:-3.00 ,X:-1.07,Y:-0.09,Z:0.43 降落
# rpy_rad[0]:-45.06,rpy_rad[1]:0.03,rpy_rad[2]:-2.91 ,X:-1.07,Y:-0.10,Z:0.42 降落
# rpy_rad[0]:-45.36,rpy_rad[1]:0.05,rpy_rad[2]:-2.95 ,X:-1.07,Y:-0.10,Z:0.42 降落
# rpy_rad[0]:-45.35,rpy_rad[1]:0.08,rpy_rad[2]:-2.95 ,X:-1.07,Y:-0.09,Z:0.42 降落
# rpy_rad[0]:-45.43,rpy_rad[1]:0.08,rpy_rad[2]:-2.96 ,X:-1.07,Y:-0.09,Z:0.42 降落
# rpy_rad[0]:-45.24,rpy_rad[1]:0.09,rpy_rad[2]:-2.95 ,X:-1.07,Y:-0.09,Z:0.42 降落
# rpy_rad[0]:-45.85,rpy_rad[1]:0.06,rpy_rad[2]:-2.99 ,X:-1.06,Y:-0.09,Z:0.43 降落
# rpy_rad[0]:-45.73,rpy_rad[1]:0.09,rpy_rad[2]:-2.99 ,X:-1.06,Y:-0.09,Z:0.44 降落
# rpy_rad[0]:-45.82,rpy_rad[1]:0.14,rpy_rad[2]:-3.00 ,X:-1.06,Y:-0.08,Z:0.43 降落
# rpy_rad[0]:-44.99,rpy_rad[1]:0.17,rpy_rad[2]:-2.95 ,X:-1.06,Y:-0.08,Z:0.41 降落
# rpy_rad[0]:-45.57,rpy_rad[1]:0.18,rpy_rad[2]:-2.99 ,X:-1.05,Y:-0.07,Z:0.42 降落
# rpy_rad[0]:-45.45,rpy_rad[1]:0.19,rpy_rad[2]:-2.99 ,X:-1.05,Y:-0.07,Z:0.42 降落
# rpy_rad[0]:-45.80,rpy_rad[1]:0.18,rpy_rad[2]:-3.01 ,X:-1.05,Y:-0.07,Z:0.43 降落
# rpy_rad[0]:-45.63,rpy_rad[1]:0.16,rpy_rad[2]:-3.01 ,X:-1.05,Y:-0.07,Z:0.43 降落
# rpy_rad[0]:-45.67,rpy_rad[1]:0.22,rpy_rad[2]:-3.01 ,X:-1.05,Y:-0.07,Z:0.42 降落
# rpy_rad[0]:-45.70,rpy_rad[1]:0.23,rpy_rad[2]:-3.02 ,X:-1.04,Y:-0.07,Z:0.42 降落
# rpy_rad[0]:-45.36,rpy_rad[1]:0.25,rpy_rad[2]:-2.97 ,X:-1.04,Y:-0.06,Z:0.42 降落
# rpy_rad[0]:-45.36,rpy_rad[1]:0.24,rpy_rad[2]:-3.01 ,X:-1.04,Y:-0.06,Z:0.42 降落
# rpy_rad[0]:-45.89,rpy_rad[1]:0.27,rpy_rad[2]:-3.02 ,X:-1.04,Y:-0.06,Z:0.43 降落
# rpy_rad[0]:-45.45,rpy_rad[1]:0.25,rpy_rad[2]:-3.04 ,X:-1.04,Y:-0.06,Z:0.43 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.29,rpy_rad[2]:-3.03 ,X:-1.03,Y:-0.06,Z:0.44 降落
# rpy_rad[0]:-45.49,rpy_rad[1]:0.29,rpy_rad[2]:-3.06 ,X:-1.03,Y:-0.05,Z:0.43 降落
# rpy_rad[0]:-45.28,rpy_rad[1]:0.33,rpy_rad[2]:-3.08 ,X:-1.03,Y:-0.05,Z:0.43 降落
# rpy_rad[0]:-45.44,rpy_rad[1]:0.31,rpy_rad[2]:-3.08 ,X:-1.02,Y:-0.05,Z:0.43 降落
# rpy_rad[0]:-45.64,rpy_rad[1]:0.34,rpy_rad[2]:-3.09 ,X:-1.02,Y:-0.05,Z:0.43 降落
# rpy_rad[0]:-45.40,rpy_rad[1]:0.30,rpy_rad[2]:-3.08 ,X:-1.02,Y:-0.05,Z:0.43 降落
# rpy_rad[0]:-45.83,rpy_rad[1]:0.34,rpy_rad[2]:-3.10 ,X:-1.02,Y:-0.04,Z:0.43 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.37,rpy_rad[2]:-3.12 ,X:-1.02,Y:-0.04,Z:0.44 降落
# rpy_rad[0]:-46.00,rpy_rad[1]:0.35,rpy_rad[2]:-3.10 ,X:-1.02,Y:-0.04,Z:0.44 降落
# rpy_rad[0]:-45.55,rpy_rad[1]:0.34,rpy_rad[2]:-3.11 ,X:-1.02,Y:-0.04,Z:0.43 降落
# rpy_rad[0]:-45.38,rpy_rad[1]:0.35,rpy_rad[2]:-3.14 ,X:-1.01,Y:-0.04,Z:0.43 降落
# rpy_rad[0]:-45.15,rpy_rad[1]:0.32,rpy_rad[2]:-3.12 ,X:-1.01,Y:-0.03,Z:0.42 降落
# rpy_rad[0]:-45.49,rpy_rad[1]:0.27,rpy_rad[2]:-3.11 ,X:-1.01,Y:-0.03,Z:0.43 降落
# rpy_rad[0]:-45.34,rpy_rad[1]:0.23,rpy_rad[2]:-3.11 ,X:-1.01,Y:-0.03,Z:0.43 降落
# rpy_rad[0]:-46.08,rpy_rad[1]:0.12,rpy_rad[2]:-3.03 ,X:-1.01,Y:-0.03,Z:0.46 降落
# rpy_rad[0]:-47.01,rpy_rad[1]:-0.01,rpy_rad[2]:-2.99 ,X:-1.01,Y:-0.04,Z:0.48 降落
# rpy_rad[0]:-45.26,rpy_rad[1]:-0.25,rpy_rad[2]:-2.99 ,X:-1.00,Y:-0.02,Z:0.43 降落
# rpy_rad[0]:-45.50,rpy_rad[1]:-0.30,rpy_rad[2]:-2.96 ,X:-1.00,Y:-0.02,Z:0.43 降落
# rpy_rad[0]:-45.33,rpy_rad[1]:-0.44,rpy_rad[2]:-2.90 ,X:-1.00,Y:-0.02,Z:0.42 降落
# rpy_rad[0]:-45.94,rpy_rad[1]:-0.71,rpy_rad[2]:-2.89 ,X:-0.99,Y:-0.02,Z:0.43 降落
# rpy_rad[0]:-45.33,rpy_rad[1]:-0.56,rpy_rad[2]:-2.91 ,X:-0.99,Y:-0.01,Z:0.41 降落
# rpy_rad[0]:-45.25,rpy_rad[1]:-0.50,rpy_rad[2]:-2.89 ,X:-0.99,Y:-0.01,Z:0.41 降落
# rpy_rad[0]:-45.06,rpy_rad[1]:-0.41,rpy_rad[2]:-2.92 ,X:-0.99,Y:-0.01,Z:0.40 降落
# rpy_rad[0]:-45.22,rpy_rad[1]:-0.27,rpy_rad[2]:-2.88 ,X:-0.98,Y:-0.00,Z:0.39 降落
# rpy_rad[0]:-45.23,rpy_rad[1]:-0.18,rpy_rad[2]:-2.88 ,X:-0.98,Y:-0.00,Z:0.39 降落
# rpy_rad[0]:-44.79,rpy_rad[1]:-0.02,rpy_rad[2]:-3.01 ,X:-0.98,Y:0.00,Z:0.37 降落
# rpy_rad[0]:-44.79,rpy_rad[1]:0.02,rpy_rad[2]:-3.07 ,X:-0.97,Y:0.00,Z:0.37 降落
# rpy_rad[0]:-45.04,rpy_rad[1]:0.15,rpy_rad[2]:-3.15 ,X:-0.97,Y:0.01,Z:0.37 降落
# rpy_rad[0]:-44.64,rpy_rad[1]:0.28,rpy_rad[2]:-3.16 ,X:-0.97,Y:0.01,Z:0.35 降落
# rpy_rad[0]:-43.89,rpy_rad[1]:0.47,rpy_rad[2]:-3.23 ,X:-0.96,Y:0.01,Z:0.33 降落
# rpy_rad[0]:-44.32,rpy_rad[1]:0.45,rpy_rad[2]:-3.30 ,X:-0.96,Y:0.02,Z:0.33 降落
# rpy_rad[0]:-44.17,rpy_rad[1]:0.54,rpy_rad[2]:-3.36 ,X:-0.95,Y:0.02,Z:0.32 降落
# rpy_rad[0]:-44.47,rpy_rad[1]:0.58,rpy_rad[2]:-3.37 ,X:-0.95,Y:0.02,Z:0.33 降落
# rpy_rad[0]:-44.15,rpy_rad[1]:0.53,rpy_rad[2]:-3.33 ,X:-0.95,Y:0.02,Z:0.31 降落
# rpy_rad[0]:-43.60,rpy_rad[1]:0.69,rpy_rad[2]:-3.43 ,X:-0.95,Y:0.02,Z:0.29 降落
# rpy_rad[0]:-44.20,rpy_rad[1]:0.74,rpy_rad[2]:-3.53 ,X:-0.94,Y:0.03,Z:0.29 降落
# rpy_rad[0]:-44.45,rpy_rad[1]:0.78,rpy_rad[2]:-3.58 ,X:-0.94,Y:0.03,Z:0.29 降落
# rpy_rad[0]:-44.45,rpy_rad[1]:0.82,rpy_rad[2]:-3.60 ,X:-0.94,Y:0.03,Z:0.29 降落
# rpy_rad[0]:-44.26,rpy_rad[1]:0.87,rpy_rad[2]:-3.59 ,X:-0.94,Y:0.03,Z:0.27 降落
# rpy_rad[0]:-43.99,rpy_rad[1]:0.93,rpy_rad[2]:-3.62 ,X:-0.94,Y:0.03,Z:0.27 降落
# rpy_rad[0]:-44.13,rpy_rad[1]:0.91,rpy_rad[2]:-3.68 ,X:-0.93,Y:0.03,Z:0.26 降落
# rpy_rad[0]:-44.55,rpy_rad[1]:0.93,rpy_rad[2]:-3.70 ,X:-0.93,Y:0.03,Z:0.26 降落
# rpy_rad[0]:-45.47,rpy_rad[1]:0.89,rpy_rad[2]:-3.71 ,X:-0.93,Y:0.03,Z:0.28 降落
# rpy_rad[0]:-44.53,rpy_rad[1]:0.90,rpy_rad[2]:-3.70 ,X:-0.93,Y:0.03,Z:0.26 降落
# rpy_rad[0]:-44.46,rpy_rad[1]:0.90,rpy_rad[2]:-3.73 ,X:-0.93,Y:0.04,Z:0.25 降落
# rpy_rad[0]:-44.25,rpy_rad[1]:1.00,rpy_rad[2]:-3.68 ,X:-0.93,Y:0.03,Z:0.25 降落
# rpy_rad[0]:-44.09,rpy_rad[1]:1.04,rpy_rad[2]:-3.69 ,X:-0.93,Y:0.03,Z:0.24 降落
# rpy_rad[0]:-44.24,rpy_rad[1]:0.99,rpy_rad[2]:-3.77 ,X:-0.93,Y:0.04,Z:0.24 降落
# rpy_rad[0]:-44.33,rpy_rad[1]:1.05,rpy_rad[2]:-3.81 ,X:-0.92,Y:0.04,Z:0.24 降落
# rpy_rad[0]:-45.23,rpy_rad[1]:0.84,rpy_rad[2]:-3.76 ,X:-0.92,Y:0.03,Z:0.23 降落
# rpy_rad[0]:-44.66,rpy_rad[1]:0.79,rpy_rad[2]:-3.72 ,X:-0.92,Y:0.03,Z:0.22 降落
# rpy_rad[0]:-44.65,rpy_rad[1]:0.85,rpy_rad[2]:-3.78 ,X:-0.92,Y:0.03,Z:0.20 降落
# rpy_rad[0]:-44.66,rpy_rad[1]:0.80,rpy_rad[2]:-3.84 ,X:-0.92,Y:0.03,Z:0.19 降落
# rpy_rad[0]:-45.05,rpy_rad[1]:0.81,rpy_rad[2]:-3.90 ,X:-0.92,Y:0.02,Z:0.20 降落
# rpy_rad[0]:-44.75,rpy_rad[1]:0.78,rpy_rad[2]:-3.80 ,X:-0.92,Y:0.02,Z:0.18 降落
# rpy_rad[0]:-44.15,rpy_rad[1]:0.76,rpy_rad[2]:-3.80 ,X:-0.92,Y:0.01,Z:0.16 降落
# rpy_rad[0]:-44.80,rpy_rad[1]:0.74,rpy_rad[2]:-3.82 ,X:-0.92,Y:0.01,Z:0.17 降落
# rpy_rad[0]:-44.97,rpy_rad[1]:0.74,rpy_rad[2]:-3.85 ,X:-0.92,Y:0.01,Z:0.17 降落
# rpy_rad[0]:-45.00,rpy_rad[1]:0.73,rpy_rad[2]:-3.84 ,X:-0.92,Y:0.00,Z:0.16 降落
# rpy_rad[0]:-44.95,rpy_rad[1]:0.73,rpy_rad[2]:-3.78 ,X:-0.92,Y:-0.00,Z:0.15 降落
# rpy_rad[0]:-45.03,rpy_rad[1]:0.75,rpy_rad[2]:-3.77 ,X:-0.92,Y:-0.01,Z:0.15 降落
# rpy_rad[0]:-45.04,rpy_rad[1]:0.75,rpy_rad[2]:-3.77 ,X:-0.92,Y:-0.01,Z:0.14 降落
# rpy_rad[0]:-44.83,rpy_rad[1]:0.76,rpy_rad[2]:-3.71 ,X:-0.92,Y:-0.01,Z:0.13 降落
# rpy_rad[0]:-44.98,rpy_rad[1]:0.77,rpy_rad[2]:-3.75 ,X:-0.92,Y:-0.01,Z:0.13 降落
# rpy_rad[0]:-45.30,rpy_rad[1]:0.75,rpy_rad[2]:-3.82 ,X:-0.92,Y:-0.01,Z:0.13 降落
# rpy_rad[0]:-45.49,rpy_rad[1]:0.71,rpy_rad[2]:-3.82 ,X:-0.92,Y:-0.01,Z:0.13 降落
# rpy_rad[0]:-45.45,rpy_rad[1]:0.58,rpy_rad[2]:-3.77 ,X:-0.92,Y:-0.01,Z:0.12 降落
# rpy_rad[0]:-45.78,rpy_rad[1]:0.54,rpy_rad[2]:-3.78 ,X:-0.92,Y:-0.01,Z:0.12 降落
# rpy_rad[0]:-45.85,rpy_rad[1]:0.50,rpy_rad[2]:-3.76 ,X:-0.92,Y:-0.02,Z:0.09 降落
# rpy_rad[0]:-45.80,rpy_rad[1]:0.49,rpy_rad[2]:-3.75 ,X:-0.92,Y:-0.02,Z:0.08 降落
# rpy_rad[0]:-45.77,rpy_rad[1]:0.48,rpy_rad[2]:-3.75 ,X:-0.92,Y:-0.02,Z:0.08 降落
# rpy_rad[0]:-46.02,rpy_rad[1]:0.52,rpy_rad[2]:-3.82 ,X:-0.92,Y:-0.02,Z:0.08 降落
# rpy_rad[0]:-46.09,rpy_rad[1]:0.51,rpy_rad[2]:-3.83 ,X:-0.92,Y:-0.02,Z:0.08 降落
# rpy_rad[0]:-46.29,rpy_rad[1]:0.49,rpy_rad[2]:-3.84 ,X:-0.92,Y:-0.02,Z:0.08 降落
# rpy_rad[0]:-46.12,rpy_rad[1]:0.40,rpy_rad[2]:-3.78 ,X:-0.92,Y:-0.03,Z:0.08 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.40,rpy_rad[2]:-3.80 ,X:-0.92,Y:-0.03,Z:0.09 降落
# rpy_rad[0]:-46.82,rpy_rad[1]:0.37,rpy_rad[2]:-3.81 ,X:-0.92,Y:-0.03,Z:0.09 降落
# rpy_rad[0]:-46.54,rpy_rad[1]:0.33,rpy_rad[2]:-3.78 ,X:-0.92,Y:-0.03,Z:0.07 降落
# rpy_rad[0]:-46.29,rpy_rad[1]:0.36,rpy_rad[2]:-3.78 ,X:-0.92,Y:-0.03,Z:0.07 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.27,rpy_rad[2]:-3.77 ,X:-0.92,Y:-0.04,Z:0.06 降落
# rpy_rad[0]:-46.45,rpy_rad[1]:0.23,rpy_rad[2]:-3.79 ,X:-0.92,Y:-0.04,Z:0.06 降落
# rpy_rad[0]:-45.52,rpy_rad[1]:0.19,rpy_rad[2]:-3.73 ,X:-0.93,Y:-0.04,Z:0.04 降落
# rpy_rad[0]:-45.50,rpy_rad[1]:0.16,rpy_rad[2]:-3.71 ,X:-0.93,Y:-0.04,Z:0.03 降落
# rpy_rad[0]:-46.07,rpy_rad[1]:0.20,rpy_rad[2]:-3.74 ,X:-0.93,Y:-0.05,Z:0.05 降落
# rpy_rad[0]:-45.84,rpy_rad[1]:0.20,rpy_rad[2]:-3.74 ,X:-0.93,Y:-0.05,Z:0.05 降落
# rpy_rad[0]:-45.96,rpy_rad[1]:0.13,rpy_rad[2]:-3.79 ,X:-0.93,Y:-0.05,Z:0.04 降落
# rpy_rad[0]:-45.96,rpy_rad[1]:0.11,rpy_rad[2]:-3.80 ,X:-0.93,Y:-0.05,Z:0.04 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.15,rpy_rad[2]:-3.75 ,X:-0.93,Y:-0.05,Z:0.05 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.12,rpy_rad[2]:-3.76 ,X:-0.93,Y:-0.06,Z:0.05 降落
# rpy_rad[0]:-47.07,rpy_rad[1]:0.02,rpy_rad[2]:-3.81 ,X:-0.93,Y:-0.06,Z:0.05 降落
# rpy_rad[0]:-46.27,rpy_rad[1]:0.10,rpy_rad[2]:-3.74 ,X:-0.93,Y:-0.07,Z:0.04 降落
# rpy_rad[0]:-46.50,rpy_rad[1]:0.16,rpy_rad[2]:-3.76 ,X:-0.93,Y:-0.08,Z:0.04 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.47,rpy_rad[2]:-3.80 ,X:-0.94,Y:-0.08,Z:0.02 降落
# rpy_rad[0]:-45.77,rpy_rad[1]:0.07,rpy_rad[2]:-3.83 ,X:-0.94,Y:-0.08,Z:0.03 降落
# rpy_rad[0]:-46.20,rpy_rad[1]:0.93,rpy_rad[2]:-3.71 ,X:-0.94,Y:-0.09,Z:0.03 降落
# rpy_rad[0]:-47.77,rpy_rad[1]:0.60,rpy_rad[2]:-3.46 ,X:-0.94,Y:-0.10,Z:0.03 降落
# rpy_rad[0]:-47.23,rpy_rad[1]:0.53,rpy_rad[2]:-3.33 ,X:-0.94,Y:-0.11,Z:0.03 降落
# rpy_rad[0]:-46.49,rpy_rad[1]:0.38,rpy_rad[2]:-3.30 ,X:-0.94,Y:-0.10,Z:-0.01 降落
# rpy_rad[0]:-46.96,rpy_rad[1]:0.41,rpy_rad[2]:-3.25 ,X:-0.95,Y:-0.10,Z:-0.02 降落
# rpy_rad[0]:-48.16,rpy_rad[1]:0.19,rpy_rad[2]:-3.26 ,X:-0.93,Y:-0.11,Z:0.04 降落
# rpy_rad[0]:-48.20,rpy_rad[1]:0.15,rpy_rad[2]:-3.43 ,X:-0.93,Y:-0.10,Z:0.04 降落
# rpy_rad[0]:-47.05,rpy_rad[1]:-0.27,rpy_rad[2]:-3.20 ,X:-0.93,Y:-0.11,Z:0.04 降落
# rpy_rad[0]:-48.22,rpy_rad[1]:-0.35,rpy_rad[2]:-3.35 ,X:-0.92,Y:-0.11,Z:0.08 降落
# rpy_rad[0]:-46.67,rpy_rad[1]:0.08,rpy_rad[2]:-3.05 ,X:-0.93,Y:-0.12,Z:0.05 降落
# rpy_rad[0]:-46.85,rpy_rad[1]:0.39,rpy_rad[2]:-3.08 ,X:-0.93,Y:-0.13,Z:0.06 降落
# rpy_rad[0]:-46.93,rpy_rad[1]:0.05,rpy_rad[2]:-3.18 ,X:-0.92,Y:-0.13,Z:0.06 降落
# rpy_rad[0]:-46.47,rpy_rad[1]:-0.22,rpy_rad[2]:-3.01 ,X:-0.92,Y:-0.13,Z:0.06 降落
# rpy_rad[0]:-46.34,rpy_rad[1]:-0.00,rpy_rad[2]:-3.00 ,X:-0.93,Y:-0.14,Z:0.06 降落
# rpy_rad[0]:-46.54,rpy_rad[1]:0.13,rpy_rad[2]:-2.96 ,X:-0.93,Y:-0.14,Z:0.07 降落
# rpy_rad[0]:-45.17,rpy_rad[1]:-0.05,rpy_rad[2]:-2.90 ,X:-0.93,Y:-0.14,Z:0.05 降落
# rpy_rad[0]:-45.47,rpy_rad[1]:0.08,rpy_rad[2]:-3.00 ,X:-0.92,Y:-0.13,Z:0.04 降落
# rpy_rad[0]:-45.92,rpy_rad[1]:0.06,rpy_rad[2]:-3.03 ,X:-0.92,Y:-0.13,Z:0.04 降落
# rpy_rad[0]:-46.45,rpy_rad[1]:0.04,rpy_rad[2]:-2.90 ,X:-0.92,Y:-0.14,Z:0.06 降落
# rpy_rad[0]:-46.04,rpy_rad[1]:-0.06,rpy_rad[2]:-2.66 ,X:-0.92,Y:-0.14,Z:0.06 降落
# rpy_rad[0]:-46.02,rpy_rad[1]:-0.09,rpy_rad[2]:-2.55 ,X:-0.92,Y:-0.15,Z:0.07 降落
# rpy_rad[0]:-46.27,rpy_rad[1]:-0.16,rpy_rad[2]:-2.48 ,X:-0.92,Y:-0.15,Z:0.07 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.01,rpy_rad[2]:-2.72 ,X:-0.91,Y:-0.13,Z:0.07 降落
# rpy_rad[0]:-46.00,rpy_rad[1]:0.09,rpy_rad[2]:-2.39 ,X:-0.91,Y:-0.15,Z:0.07 降落
# rpy_rad[0]:-46.01,rpy_rad[1]:-0.10,rpy_rad[2]:-2.49 ,X:-0.91,Y:-0.14,Z:0.08 降落
# rpy_rad[0]:-46.14,rpy_rad[1]:0.06,rpy_rad[2]:-2.46 ,X:-0.91,Y:-0.14,Z:0.07 降落
# rpy_rad[0]:-46.04,rpy_rad[1]:0.05,rpy_rad[2]:-2.48 ,X:-0.90,Y:-0.15,Z:0.08 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.05,rpy_rad[2]:-2.54 ,X:-0.90,Y:-0.14,Z:0.08 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.06,rpy_rad[2]:-2.50 ,X:-0.90,Y:-0.15,Z:0.08 降落
# rpy_rad[0]:-46.11,rpy_rad[1]:0.04,rpy_rad[2]:-2.53 ,X:-0.90,Y:-0.15,Z:0.08 降落
# rpy_rad[0]:-46.01,rpy_rad[1]:0.04,rpy_rad[2]:-2.52 ,X:-0.90,Y:-0.15,Z:0.08 降落
# rpy_rad[0]:-45.98,rpy_rad[1]:0.08,rpy_rad[2]:-2.54 ,X:-0.90,Y:-0.15,Z:0.08 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.09,rpy_rad[2]:-2.47 ,X:-0.90,Y:-0.15,Z:0.08 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.04,rpy_rad[2]:-2.49 ,X:-0.90,Y:-0.15,Z:0.09 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.03,rpy_rad[2]:-2.49 ,X:-0.90,Y:-0.15,Z:0.09 降落
# rpy_rad[0]:-46.15,rpy_rad[1]:0.08,rpy_rad[2]:-2.46 ,X:-0.90,Y:-0.15,Z:0.09 降落
# rpy_rad[0]:-46.08,rpy_rad[1]:0.10,rpy_rad[2]:-2.45 ,X:-0.90,Y:-0.15,Z:0.09 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.06,rpy_rad[2]:-2.48 ,X:-0.90,Y:-0.15,Z:0.09 降落
# rpy_rad[0]:-46.06,rpy_rad[1]:0.10,rpy_rad[2]:-2.45 ,X:-0.90,Y:-0.15,Z:0.09 降落
# rpy_rad[0]:-46.13,rpy_rad[1]:0.10,rpy_rad[2]:-2.41 ,X:-0.90,Y:-0.15,Z:0.09 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.11,rpy_rad[2]:-2.44 ,X:-0.91,Y:-0.15,Z:0.09 降落
# rpy_rad[0]:-46.03,rpy_rad[1]:0.09,rpy_rad[2]:-2.42 ,X:-0.91,Y:-0.15,Z:0.09 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.11,rpy_rad[2]:-2.48 ,X:-0.91,Y:-0.15,Z:0.09 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.49 ,X:-0.91,Y:-0.15,Z:0.09 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.12,rpy_rad[2]:-2.43 ,X:-0.90,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.12,rpy_rad[1]:0.13,rpy_rad[2]:-2.41 ,X:-0.90,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.48 ,X:-0.90,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.07,rpy_rad[1]:0.13,rpy_rad[2]:-2.40 ,X:-0.90,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.20,rpy_rad[1]:0.12,rpy_rad[2]:-2.44 ,X:-0.90,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.14,rpy_rad[1]:0.13,rpy_rad[2]:-2.42 ,X:-0.91,Y:-0.16,Z:0.10 降落
# rpy_rad[0]:-46.15,rpy_rad[1]:0.15,rpy_rad[2]:-2.40 ,X:-0.91,Y:-0.16,Z:0.10 降落
# rpy_rad[0]:-46.05,rpy_rad[1]:0.14,rpy_rad[2]:-2.39 ,X:-0.91,Y:-0.16,Z:0.10 降落
# rpy_rad[0]:-46.14,rpy_rad[1]:0.15,rpy_rad[2]:-2.41 ,X:-0.91,Y:-0.16,Z:0.10 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.14,rpy_rad[2]:-2.43 ,X:-0.91,Y:-0.16,Z:0.10 降落
# rpy_rad[0]:-46.14,rpy_rad[1]:0.16,rpy_rad[2]:-2.40 ,X:-0.91,Y:-0.16,Z:0.10 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.13,rpy_rad[2]:-2.45 ,X:-0.91,Y:-0.16,Z:0.10 降落
# rpy_rad[0]:-46.14,rpy_rad[1]:0.14,rpy_rad[2]:-2.42 ,X:-0.91,Y:-0.16,Z:0.10 降落
# rpy_rad[0]:-46.15,rpy_rad[1]:0.13,rpy_rad[2]:-2.44 ,X:-0.91,Y:-0.16,Z:0.10 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.14,rpy_rad[2]:-2.44 ,X:-0.91,Y:-0.16,Z:0.10 降落
# rpy_rad[0]:-46.13,rpy_rad[1]:0.13,rpy_rad[2]:-2.44 ,X:-0.91,Y:-0.16,Z:0.10 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.14,rpy_rad[2]:-2.43 ,X:-0.91,Y:-0.16,Z:0.10 降落
# rpy_rad[0]:-46.11,rpy_rad[1]:0.14,rpy_rad[2]:-2.41 ,X:-0.91,Y:-0.16,Z:0.10 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.14,rpy_rad[2]:-2.46 ,X:-0.91,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.12,rpy_rad[1]:0.14,rpy_rad[2]:-2.42 ,X:-0.91,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.14,rpy_rad[2]:-2.44 ,X:-0.91,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.15,rpy_rad[2]:-2.43 ,X:-0.91,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.15,rpy_rad[2]:-2.42 ,X:-0.91,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.15,rpy_rad[1]:0.13,rpy_rad[2]:-2.44 ,X:-0.91,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.15,rpy_rad[1]:0.14,rpy_rad[2]:-2.44 ,X:-0.91,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.12,rpy_rad[1]:0.13,rpy_rad[2]:-2.44 ,X:-0.91,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.11,rpy_rad[1]:0.15,rpy_rad[2]:-2.43 ,X:-0.91,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.09,rpy_rad[1]:0.14,rpy_rad[2]:-2.41 ,X:-0.91,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.12,rpy_rad[2]:-2.44 ,X:-0.91,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.13,rpy_rad[2]:-2.45 ,X:-0.90,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.15,rpy_rad[1]:0.15,rpy_rad[2]:-2.42 ,X:-0.91,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.10,rpy_rad[1]:0.11,rpy_rad[2]:-2.45 ,X:-0.91,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.12,rpy_rad[1]:0.13,rpy_rad[2]:-2.44 ,X:-0.91,Y:-0.15,Z:0.10 降落
# rpy_rad[0]:-46.15,rpy_rad[1]:0.15,rpy_rad[2]:-2.43 ,X:-0.91,Y:-0.15,Z:0.11 降落
# rpy_rad[0]:-46.15,rpy_rad[1]:0.14,rpy_rad[2]:-2.43 ,X:-0.91,Y:-0.15,Z:0.11 降落
# rpy_rad[0]:-46.13,rpy_rad[1]:0.14,rpy_rad[2]:-2.45 ,X:-0.91,Y:-0.15,Z:0.11 降落
# rpy_rad[0]:-46.13,rpy_rad[1]:0.15,rpy_rad[2]:-2.44 ,X:-0.91,Y:-0.15,Z:0.11 降落
# rpy_rad[0]:-46.13,rpy_rad[1]:0.14,rpy_rad[2]:-2.42 ,X:-0.91,Y:-0.15,Z:0.11 降落
# rpy_rad[0]:-46.14,rpy_rad[1]:0.17,rpy_rad[2]:-2.43 ,X:-0.91,Y:-0.15,Z:0.11 降落
# rpy_rad[0]:-46.15,rpy_rad[1]:0.15,rpy_rad[2]:-2.44 ,X:-0.91,Y:-0.15,Z:0.12 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.15,rpy_rad[2]:-2.45 ,X:-0.91,Y:-0.15,Z:0.12 降落
# rpy_rad[0]:-46.15,rpy_rad[1]:0.18,rpy_rad[2]:-2.42 ,X:-0.91,Y:-0.15,Z:0.12 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.16,rpy_rad[2]:-2.41 ,X:-0.91,Y:-0.16,Z:0.12 降落
# rpy_rad[0]:-46.13,rpy_rad[1]:0.15,rpy_rad[2]:-2.41 ,X:-0.91,Y:-0.16,Z:0.12 降落
# rpy_rad[0]:-46.12,rpy_rad[1]:0.17,rpy_rad[2]:-2.42 ,X:-0.91,Y:-0.16,Z:0.12 降落
# rpy_rad[0]:-46.15,rpy_rad[1]:0.16,rpy_rad[2]:-2.42 ,X:-0.91,Y:-0.15,Z:0.12 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.15,rpy_rad[2]:-2.43 ,X:-0.91,Y:-0.15,Z:0.12 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.18,rpy_rad[2]:-2.42 ,X:-0.91,Y:-0.15,Z:0.12 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.19,rpy_rad[2]:-2.41 ,X:-0.91,Y:-0.15,Z:0.12 降落
# rpy_rad[0]:-46.15,rpy_rad[1]:0.17,rpy_rad[2]:-2.42 ,X:-0.91,Y:-0.15,Z:0.12 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.17,rpy_rad[2]:-2.42 ,X:-0.91,Y:-0.16,Z:0.12 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.16,rpy_rad[2]:-2.41 ,X:-0.91,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.18,rpy_rad[2]:-2.41 ,X:-0.91,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.18,rpy_rad[2]:-2.40 ,X:-0.91,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.17,rpy_rad[2]:-2.41 ,X:-0.91,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.18,rpy_rad[2]:-2.41 ,X:-0.91,Y:-0.16,Z:0.12 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.18,rpy_rad[2]:-2.40 ,X:-0.91,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.17,rpy_rad[2]:-2.40 ,X:-0.91,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.18,rpy_rad[2]:-2.40 ,X:-0.91,Y:-0.15,Z:0.13 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.19,rpy_rad[2]:-2.40 ,X:-0.92,Y:-0.15,Z:0.13 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.19,rpy_rad[2]:-2.39 ,X:-0.92,Y:-0.15,Z:0.13 降落
# rpy_rad[0]:-46.15,rpy_rad[1]:0.18,rpy_rad[2]:-2.38 ,X:-0.92,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.19,rpy_rad[2]:-2.38 ,X:-0.92,Y:-0.15,Z:0.13 降落
# rpy_rad[0]:-46.15,rpy_rad[1]:0.19,rpy_rad[2]:-2.38 ,X:-0.92,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.18,rpy_rad[2]:-2.39 ,X:-0.92,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.19,rpy_rad[2]:-2.38 ,X:-0.92,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.19,rpy_rad[2]:-2.37 ,X:-0.92,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.19,rpy_rad[2]:-2.37 ,X:-0.92,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.20,rpy_rad[2]:-2.36 ,X:-0.92,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.20,rpy_rad[2]:-2.36 ,X:-0.92,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.19,rpy_rad[2]:-2.36 ,X:-0.92,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.20,rpy_rad[2]:-2.36 ,X:-0.92,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.20,rpy_rad[2]:-2.37 ,X:-0.92,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.20,rpy_rad[2]:-2.36 ,X:-0.92,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.20,rpy_rad[2]:-2.36 ,X:-0.92,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.16,rpy_rad[1]:0.20,rpy_rad[2]:-2.36 ,X:-0.92,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.20,rpy_rad[2]:-2.36 ,X:-0.92,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.20,rpy_rad[2]:-2.36 ,X:-0.92,Y:-0.16,Z:0.13 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.20,rpy_rad[2]:-2.36 ,X:-0.92,Y:-0.16,Z:0.14 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.21,rpy_rad[2]:-2.36 ,X:-0.92,Y:-0.16,Z:0.14 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.20,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.16,Z:0.14 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.20,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.16,Z:0.14 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.20,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.16,Z:0.14 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.20,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.16,Z:0.14 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.19,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.16,Z:0.14 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.19,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.16,Z:0.14 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.20,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.16,Z:0.14 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.19,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.16,Z:0.14 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.20,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.16,Z:0.14 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.20,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.16,Z:0.14 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.20,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.16,Z:0.14 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.20,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.16,Z:0.14 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.20,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.14 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.20,rpy_rad[2]:-2.34 ,X:-0.92,Y:-0.17,Z:0.14 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.19,rpy_rad[2]:-2.35 ,X:-0.92,Y:-0.17,Z:0.14 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.20,rpy_rad[2]:-2.35 ,X:-0.92,Y:-0.17,Z:0.14 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.19,rpy_rad[2]:-2.35 ,X:-0.92,Y:-0.17,Z:0.14 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.20,rpy_rad[2]:-2.34 ,X:-0.92,Y:-0.17,Z:0.14 降落
# rpy_rad[0]:-46.17,rpy_rad[1]:0.20,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.14 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.19,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.14 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.19,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.16,Z:0.14 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.19,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.17,Z:0.14 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.19,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.14 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.19,rpy_rad[2]:-2.34 ,X:-0.92,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.19,rpy_rad[2]:-2.35 ,X:-0.92,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.18,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.19,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.19,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.18,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.19,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.18,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.18,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.19,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.18,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.18,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.18,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.18,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.18,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.18,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.18,rpy_rad[1]:0.18,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.18,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.18,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.18,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.18,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.18,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.18,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.18,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.17,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.17,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.17,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.17,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.17,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.17,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.17,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.17,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.17,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.17,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.16,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.17,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.17,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.17,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.17,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.17,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.17,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.16,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.16,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.16,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.16,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.15 降落
# rpy_rad[0]:-46.20,rpy_rad[1]:0.16,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.19,rpy_rad[1]:0.16,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.20,rpy_rad[1]:0.16,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.20,rpy_rad[1]:0.16,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.20,rpy_rad[1]:0.16,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.20,rpy_rad[1]:0.16,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.20,rpy_rad[1]:0.17,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.20,rpy_rad[1]:0.17,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.20,rpy_rad[1]:0.17,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.17,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.16,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.16,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.16,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.17,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.16,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.16,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.16,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.16,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.16,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.15,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.15,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.16 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.15,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.15,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.15,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.15,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.21,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.15,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.15,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.14,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.14,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.14,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.14,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.14,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.14,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.14,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.18,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.18,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.12,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.12,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.13,rpy_rad[2]:-2.32 ,X:-0.94,Y:-0.17,Z:0.17 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.13,rpy_rad[2]:-2.31 ,X:-0.94,Y:-0.17,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.13,rpy_rad[2]:-2.31 ,X:-0.93,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.13,rpy_rad[2]:-2.31 ,X:-0.93,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.13,rpy_rad[2]:-2.31 ,X:-0.94,Y:-0.17,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.13,rpy_rad[2]:-2.31 ,X:-0.94,Y:-0.17,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.13,rpy_rad[2]:-2.31 ,X:-0.93,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.13,rpy_rad[2]:-2.31 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.13,rpy_rad[2]:-2.31 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.13,rpy_rad[2]:-2.31 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.13,rpy_rad[2]:-2.31 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.31 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.30 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.30 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.30 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.13,rpy_rad[2]:-2.30 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.30 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.30 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.31 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.30 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.31 ,X:-0.93,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.13,rpy_rad[2]:-2.31 ,X:-0.93,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.31 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.31 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.31 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.31 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.31 ,X:-0.94,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.13,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.18 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.13,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.32 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.10,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.10,rpy_rad[2]:-2.33 ,X:-0.93,Y:-0.18,Z:0.19 降落
# ...
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.37 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.37 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.37 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.26,rpy_rad[1]:0.12,rpy_rad[2]:-2.37 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.26,rpy_rad[1]:0.12,rpy_rad[2]:-2.37 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.26,rpy_rad[1]:0.12,rpy_rad[2]:-2.37 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.37 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.37 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.37 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.37 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.37 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.26,rpy_rad[1]:0.12,rpy_rad[2]:-2.37 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.26,rpy_rad[1]:0.12,rpy_rad[2]:-2.37 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.26,rpy_rad[1]:0.12,rpy_rad[2]:-2.37 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.26,rpy_rad[1]:0.12,rpy_rad[2]:-2.37 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.26,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.26,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.26,rpy_rad[1]:0.13,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.13,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.13,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.13,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.13,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.13,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.13,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.13,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.13,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.13,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.13,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.13,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.13,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.13,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.25,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.12,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.11,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.10,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.10,rpy_rad[2]:-2.34 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.10,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.10,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.10,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.10,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.10,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.10,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.09,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.10,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.09,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.09,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.09,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.09,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.09,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.09,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.09,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.09,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.09,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.09,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.09,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.09,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.09,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.09,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.09,rpy_rad[2]:-2.35 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.09,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.09,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.09,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.09,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.34 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.24,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.08,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.09,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.09,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.23,rpy_rad[1]:0.09,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.09,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.09,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.09,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.09,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.09,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.09,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.09,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落
# rpy_rad[0]:-46.22,rpy_rad[1]:0.09,rpy_rad[2]:-2.36 ,X:-0.93,Y:-0.21,Z:0.33 降落

# %%
# !pip3 install transformations
# !pip3 install --upgrade numpy
# !sudo apt-get install libatlas-base-dev -y

# %%
import pyrealsense2 as rs
import ipywidgets
import ipywidgets as widgets	# 控件库
from IPython.display import display	# 显示控件的方法
import DataDeal265 as dd
# Declare RealSense pipeline, encapsulating the actual device and sensors
pipe = rs.pipeline()
# Build config object and request pose data
cfg = rs.config()
cfg.enable_stream(rs.stream.pose)

# Start streaming with requested config
pipe.start(cfg)
btn = widgets.Button(description = "OK", tooltip = 'this is a button')
def btn_click(sender):
    file=open("measuredPoint.txt",mode = 'a')
    file.write(tarx)
    file.write(tary)
    file.write("\n")
    file.close()
    print("ok")
btn.on_click(btn_click)
display(btn)
try:
    while 1:
        # Wait for the next set of frames from the camera
        frames = pipe.wait_for_frames()

        # Fetch pose frame
        pose = frames.get_pose_frame()
        if pose:
            # Print some of the pose data to the terminal
            data = pose.get_pose_data()
            # dataBuf,pos_X,pos_Y,pos_Z,Euler=dd.solveData(data)
            tarx=data.translation.z
            tary=data.translation.x
            print("\rPosition: {}".format(data.translation),end="")
            
        #time.sleep(1/freq)

finally:
    print("some erro")
# Out:
# Button(description='OK', style=ButtonStyle(), tooltip='this is a button')
# Position: x: 0.0204039, y: 0.0178773, z: -0.007844881914594
